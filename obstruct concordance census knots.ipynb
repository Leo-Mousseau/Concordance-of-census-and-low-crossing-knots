# %%
import csv
import ast
from itertools import combinations_with_replacement
import snappy

### braid operations

def mirror(braid_word):
    return([-x for x in braid_word])
def reverse_orientation(braid_word):
    return(braid_word[::-1])
def connected_sum(w1,w2):
    n=max([abs(k) for k in w1])
    w3=[k+n if k>0 else -(-k+n) for k in w2]
    return(w1+w3)

### ---- Load Invariants ----

def load_csv_as_dict(path, key_index=0, val_index=1, eval_value=True, cast=int):
    data = []
    with open(path, 'r') as f:
        reader = csv.reader(f)
        for row in reader:
            try:
                key = row[key_index]
                val = row[val_index]
                if eval_value:
                    val = ast.literal_eval(val)
                if cast:
                    val = cast(val)
                data.append((key, val))
            except:
                continue
    return dict(data)

# Paths
base_path = '/Users/leomousseau/Desktop/slice genera part 2/census seminar github'
group_path = base_path + '/group_A/computed results'
knot_floer_path = '/Users/leomousseau/Desktop/slice genera part 2/knot_floer.csv'
braid_path = base_path + '/braid_words.txt'

# Load braid words
with open(braid_path, 'r') as f:
    braid_words_list = ast.literal_eval(f.read())
braid_dict = dict(braid_words_list)
names = list(braid_dict.keys())

# Load invariants
s_dict = load_csv_as_dict('/Users/leomousseau/Downloads/sinvariants.csv')
sign_dict = load_csv_as_dict(group_path + '/signature.csv', eval_value=True, cast=int)

# From knot floer
knot_floer = []
with open(knot_floer_path, 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        knot_floer.append(row)

tau_dict = {}
eps_dict = {}
for row in knot_floer:
    name = row[0]
    try:
        tau_dict[name] = int(ast.literal_eval(row[7]))
    except:
        pass
    try:
        eps_dict[name] = int(ast.literal_eval(row[2]))
    except:
        pass

### ---- Concordance Filtering ----

variant_types = [
    ('identity', False),
    ('reverse', False),
    ('mirror', True),
    ('reverse_mirror', True)
]

slice_census = [
    'm032', 'm222', 'm372', 's704', 's879', 'v1971', 'v2272', 'v2362', 'v2508', 'v2543', 'v2861', 'v3195',
    'v3423', 'v3536', 't07281', 't07452', 't07599', 't08306', 't08617', 't10887', 't10974', 't11248', 
    't11418', 't11532', 't11577', 't12200', 't12587', 't12607', 't12630', 't12748', 'o9_12414', 'o9_18772', 
    'o9_18931', 'o9_20458', 'o9_20894', 'o9_22066', 'o9_29992', 'o9_30430', 'o9_31828', 'o9_34949', 
    'o9_35240', 'o9_36180', 'o9_36357', 'o9_36459', 'o9_37618', 'o9_37770', 'o9_38600', 'o9_39433', 
    'o9_39806', 'o9_39930', 'o9_39967', 'o9_40361', 'o9_40519', 'o9_40873', 'o9_41312', 'o9_41909', 
    'o9_42515', 'o9_42735', 'o9_43407', 'o9_43446'
]

def maybe_negate(x, flip):
    return -x if (x is not None and flip) else x

def get_variant_invariants(k2, flip):
    return {
        's-invariant': maybe_negate(s_dict.get(k2), flip),
        'signature': maybe_negate(sign_dict.get(k2), flip),
        'tau': maybe_negate(tau_dict.get(k2), flip),
        'epsilon': maybe_negate(eps_dict.get(k2), flip)
    }

### ---- Generate All Pairs ----

all_pairs = [(k1, k2, variant) for k1, k2 in combinations_with_replacement(names, 2) for variant, _ in variant_types]
print(f"Total pairs: {len(all_pairs)}")

# Filter out slice knots, since obviously, all slice knots will be concordant
non_slice_pairs = [(k1, k2, v) for (k1, k2, v) in all_pairs if k1 not in slice_census and k2 not in slice_census]
print(f"After removing slice knots: {len(non_slice_pairs)}")

# Remove trivial identity pairs
filtered_pairs = [(k1, k2, v) for (k1, k2, v) in non_slice_pairs if not (k1 == k2 and v == 'identity')]
print(f"After removing (k,k,'identity') pairs: {len(filtered_pairs)}")

### ---- Classification ----

not_smoothly_concordant = []
not_topologically_concordant = []
possibly_smoothly_concordant = []
possibly_topologically_concordant = []

invariant_dicts = {
    's-invariant': s_dict,
    'tau': tau_dict,
    'epsilon': eps_dict,
    'signature': sign_dict
}

for k1, k2, variant in filtered_pairs:
    flip = dict(variant_types)[variant]
    k2_inv = get_variant_invariants(k2, flip)

    # Check all invariants for smooth concordance (including signature!)
    smooth_fail = None
    for inv_name in ['s-invariant', 'tau', 'epsilon', 'signature']:
        val1 = invariant_dicts[inv_name].get(k1)
        val2 = k2_inv[inv_name]
        if val1 is not None and val2 is not None and val1 != val2:
            smooth_fail = f"{inv_name}: {val1} vs {val2}"
            break

    if smooth_fail:
        not_smoothly_concordant.append((k1, k2, variant, smooth_fail))
    else:
        possibly_smoothly_concordant.append((k1, k2, variant))

    # For topological concordance, only signature matters
    sig1 = sign_dict.get(k1)
    sig2 = k2_inv['signature']
    if sig1 is not None and sig2 is not None and sig1 != sig2:
        not_topologically_concordant.append((k1, k2, variant, f"signature: {sig1} vs {sig2}"))
    else:
        possibly_topologically_concordant.append((k1, k2, variant))

### ---- Print Final Counts ----

print(f"\nFinal Counts:")
print(f"✔️ Possibly smoothly concordant: {len(possibly_smoothly_concordant)}")
print(f"❌ Not smoothly concordant: {len(not_smoothly_concordant)}")
print(f"✔️ Possibly topologically concordant: {len(possibly_topologically_concordant)}")
print(f"❌ Not topologically concordant: {len(not_topologically_concordant)}")
# Out:
# Total pairs: 3213112
# After removing slice knots: 2916112
# After removing (k,k,'identity') pairs: 2914905
#
# Final Counts:
# ✔️ Possibly smoothly concordant: 29537
# ❌ Not smoothly concordant: 2885368
# ✔️ Possibly topologically concordant: 64037
# ❌ Not topologically concordant: 2850868

# %%
not_topologically_concordant[524]
# Out:
# ('m004', 'v2090', 'identity', 'signature: 0 vs 60')

# %%
not_smoothly_concordant[4321]
# Out:
# ('m004', 'o9_40449', 'reverse', 'tau: 0 vs 1')

# %%
import time  # <-- Add this at the top with other imports if not already imported

### ---- Further Obstruct with HKL ----

hkl_obstructed = []
still_possibly_topological = []
still_possibly_smooth = []

for index, (k1, k2, variant) in enumerate(possibly_topologically_concordant[20627:], 1):
    print(f"\n🔄 [{index}/{len(possibly_topologically_concordant)}] Working on: {k1}, {k2}, {variant}")
    
    start_time = time.time()  # <-- Start timing here

    try:
        w1 = braid_dict[k1]
        if variant == 'identity':
            w2 = braid_dict[k2]
        elif variant == 'reverse':
            w2 = reverse_orientation(braid_dict[k2])
        elif variant == 'mirror':
            w2 = mirror(braid_dict[k2])
        elif variant == 'reverse_mirror':
            w2 = reverse_orientation(mirror(braid_dict[k2]))
        else:
            continue

        w = connected_sum(w1, reverse_orientation(mirror(w2)))
        K = snappy.Link(braid_closure=w)
        K.simplify('global')
        M = K.exterior()
        M.randomize()

        success = False
        max_attempts = 5
        for attempt in range(max_attempts):
            try:
                print(f"⏳ Attempt {attempt+1} running HKL...")
                obstr = M.slice_obstruction_HKL([(20, [0, 20])], verbose=True)
                if isinstance(obstr, tuple):
                    hkl_obstructed.append((k1, k2, variant, f"HKL obstruction {obstr}"))
                    print("🟩 Obstruction found!", obstr)
                else:
                    still_possibly_topological.append((k1, k2, variant))
                    still_possibly_smooth.append((k1, k2, variant))
                    print("🟥 No obstruction.")
                success = True
                break
            except Exception as e:
                print(f"⚠️ Attempt {attempt+1} failed: {e}")
                M.randomize()

        if not success:
            print(f"❌ HKL permanently failed for {k1}, {k2}, {variant}")
            still_possibly_topological.append((k1, k2, variant))
            still_possibly_smooth.append((k1, k2, variant))

    except Exception as e:
        print(f"💥 Critical setup failure for {k1}, {k2}, {variant}: {e}")
        still_possibly_topological.append((k1, k2, variant))
        still_possibly_smooth.append((k1, k2, variant))

    elapsed = time.time() - start_time  # <-- End timing here
    print(f"⏱️ Time taken: {elapsed:.2f} seconds")

    # Save results after each iteration
    with open("hkl_obstructed_2.csv", "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Knot1", "Knot2", "Variant", "Obstruction"])
        writer.writerows(hkl_obstructed)

    with open("still_possibly_topological_2.csv", "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Knot1", "Knot2", "Variant"])
        writer.writerows(still_possibly_topological)

    with open("still_possibly_smooth_2.csv", "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Knot1", "Knot2", "Variant"])
        writer.writerows(still_possibly_smooth)

### ---- Final Output ----

print("\n🔍 HKL filtering done.")
print(f"🧱 HKL obstructed (not topologically concordant): {len(hkl_obstructed)}")
print(f"🟢 Remaining possibly topologically concordant: {len(still_possibly_topological)}")
print(f"🟢 Remaining possibly smoothly concordant: {len(still_possibly_smooth)}")
# Out:
# 🔄 [1/64037] Working on: t00423, o9_04435, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (13, 3) ...
# 🟩 Obstruction found! (13, 3)
# ⏱️ Time taken: 477.39 seconds
#
# 🔄 [2/64037] Working on: t00423, o9_04435, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (13, 3) ...
# 🟩 Obstruction found! (13, 3)
# ⏱️ Time taken: 925.79 seconds
#
# 🔄 [3/64037] Working on: t00423, o9_07943, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 2.01 seconds
#
# 🔄 [4/64037] Working on: t00423, o9_07943, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 1.81 seconds
#
# 🔄 [5/64037] Working on: t00423, o9_08224, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 5) ...
# 🟩 Obstruction found! (3, 5)
# ⏱️ Time taken: 17.03 seconds
#
# 🔄 [6/64037] Working on: t00423, o9_08224, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 5) ...
# 🟩 Obstruction found! (3, 5)
# ⏱️ Time taken: 5.68 seconds
#
# 🔄 [7/64037] Working on: t00423, o9_11570, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 13.19 seconds
#
# 🔄 [8/64037] Working on: t00423, o9_11570, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 8.03 seconds
#
# 🔄 [9/64037] Working on: t00423, o9_13649, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 11.84 seconds
#
# 🔄 [10/64037] Working on: t00423, o9_13649, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 7.86 seconds
#
# 🔄 [11/64037] Working on: t00423, o9_18007, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 3.83 seconds
#
# 🔄 [12/64037] Working on: t00423, o9_18007, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 4.78 seconds
#
# 🔄 [13/64037] Working on: t00423, o9_20029, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 7) ...
# 🟩 Obstruction found! (2, 7)
# ⏱️ Time taken: 9.47 seconds
#
# 🔄 [14/64037] Working on: t00423, o9_20029, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 7) ...
# 🟩 Obstruction found! (2, 7)
# ⏱️ Time taken: 11.47 seconds
#
# 🔄 [15/64037] Working on: t00423, o9_24126, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 27.17 seconds
#
# 🔄 [16/64037] Working on: t00423, o9_24126, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 58.68 seconds
#
# 🔄 [17/64037] Working on: t00423, o9_27155, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 7) ...
# 🟩 Obstruction found! (3, 7)
# ⏱️ Time taken: 10.32 seconds
#
# 🔄 [18/64037] Working on: t00423, o9_27155, reverse
# ⏳ Attempt 1 running HKL...
# ⚠️ Attempt 1 failed: The (1, 0) filling is not obviously S^3
# ⏳ Attempt 2 running HKL...
#    Looking at (3, 7) ...
# 🟩 Obstruction found! (3, 7)
# ⏱️ Time taken: 65.51 seconds
#
# 🔄 [19/64037] Working on: t00434, t00434, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (7, 13) ...
#    Looking at (13, 5) ...
# 🟥 No obstruction.
# ⏱️ Time taken: 3.48 seconds
#
# 🔄 [20/64037] Working on: t00434, t10985, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 25.52 seconds
#
# 🔄 [21/64037] Working on: t00434, t10985, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 27.94 seconds
#
# 🔄 [22/64037] Working on: t00434, o9_03622, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 6.29 seconds
#
# 🔄 [23/64037] Working on: t00434, o9_03622, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 6.21 seconds
#
# 🔄 [24/64037] Working on: t00434, o9_08302, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 5) ...
# 🟩 Obstruction found! (3, 5)
# ⏱️ Time taken: 43.81 seconds
#
# 🔄 [25/64037] Working on: t00434, o9_08302, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 5) ...
# 🟩 Obstruction found! (3, 5)
# ⏱️ Time taken: 20.81 seconds
#
# 🔄 [26/64037] Working on: t00434, o9_12736, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 11) ...
# 🟩 Obstruction found! (3, 11)
# ⏱️ Time taken: 33.00 seconds
#
# 🔄 [27/64037] Working on: t00434, o9_12736, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 11) ...
# 🟩 Obstruction found! (3, 11)
# ⏱️ Time taken: 19.90 seconds
#
# 🔄 [28/64037] Working on: t00434, o9_13052, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 7) ...
# 🟩 Obstruction found! (3, 7)
# ⏱️ Time taken: 25.82 seconds
#
# 🔄 [29/64037] Working on: t00434, o9_13052, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 7) ...
# 🟩 Obstruction found! (3, 7)
# ⏱️ Time taken: 38.42 seconds
#
# 🔄 [30/64037] Working on: t00434, o9_13125, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (5, 11) ...
# 🟩 Obstruction found! (5, 11)
# ⏱️ Time taken: 146.01 seconds
#
# 🔄 [31/64037] Working on: t00434, o9_13125, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (5, 11) ...
# 🟩 Obstruction found! (5, 11)
# ⏱️ Time taken: 110.28 seconds
#
# 🔄 [32/64037] Working on: t00434, o9_13604, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 6.79 seconds
#
# 🔄 [33/64037] Working on: t00434, o9_13604, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 7.28 seconds
#
# 🔄 [34/64037] Working on: t00434, o9_13639, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 8.64 seconds
#
# 🔄 [35/64037] Working on: t00434, o9_13639, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 11.48 seconds
#
# 🔄 [36/64037] Working on: t00434, o9_14495, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 9.29 seconds
#
# 🔄 [37/64037] Working on: t00434, o9_14495, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 8.25 seconds
#
# 🔄 [38/64037] Working on: t00434, o9_18209, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 17.79 seconds
#
# 🔄 [39/64037] Working on: t00434, o9_18209, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 30.20 seconds
#
# 🔄 [40/64037] Working on: t00434, o9_24149, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 7.20 seconds
#
# 🔄 [41/64037] Working on: t00434, o9_24149, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 7.30 seconds
#
# 🔄 [42/64037] Working on: t00434, o9_26791, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (7, 13) ...
# 🟩 Obstruction found! (7, 13)
# ⏱️ Time taken: 158.36 seconds
#
# 🔄 [43/64037] Working on: t00434, o9_26791, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (7, 13) ...
# 🟩 Obstruction found! (7, 13)
# ⏱️ Time taken: 173.03 seconds
#
# 🔄 [44/64037] Working on: t00550, t00550, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 2) ...
#    Looking at (3, 5) ...
#    Looking at (7, 13) ...
# 🟥 No obstruction.
# ⏱️ Time taken: 0.32 seconds
#
# 🔄 [45/64037] Working on: t00550, t01966, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 11) ...
# 🟩 Obstruction found! (2, 11)
# ⏱️ Time taken: 0.85 seconds
#
# 🔄 [46/64037] Working on: t00550, t01966, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 11) ...
# 🟩 Obstruction found! (2, 11)
# ⏱️ Time taken: 0.76 seconds
#
# 🔄 [47/64037] Working on: t00550, t03106, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 11) ...
# 🟩 Obstruction found! (2, 11)
# ⏱️ Time taken: 0.56 seconds
#
# 🔄 [48/64037] Working on: t00550, t03106, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 11) ...
# 🟩 Obstruction found! (2, 11)
# ⏱️ Time taken: 0.91 seconds
#
# 🔄 [49/64037] Working on: t00550, t03710, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 4.04 seconds
#
# 🔄 [50/64037] Working on: t00550, t03710, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.48 seconds
#
# 🔄 [51/64037] Working on: t00550, t09126, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 7) ...
# 🟩 Obstruction found! (2, 7)
# ⏱️ Time taken: 1.23 seconds
#
# 🔄 [52/64037] Working on: t00550, t09126, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 7) ...
# 🟩 Obstruction found! (2, 7)
# ⏱️ Time taken: 1.27 seconds
#
# 🔄 [53/64037] Working on: t00550, o9_08497, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 11) ...
# 🟩 Obstruction found! (2, 11)
# ⏱️ Time taken: 2.92 seconds
#
# 🔄 [54/64037] Working on: t00550, o9_08497, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 11) ...
# 🟩 Obstruction found! (2, 11)
# ⏱️ Time taken: 1.68 seconds
#
# 🔄 [55/64037] Working on: t00550, o9_09052, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 7) ...
# 🟩 Obstruction found! (2, 7)
# ⏱️ Time taken: 0.67 seconds
#
# 🔄 [56/64037] Working on: t00550, o9_09052, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 7) ...
# 🟩 Obstruction found! (2, 7)
# ⏱️ Time taken: 0.54 seconds
#
# 🔄 [57/64037] Working on: t00550, o9_16514, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.49 seconds
#
# 🔄 [58/64037] Working on: t00550, o9_16514, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.34 seconds
#
# 🔄 [59/64037] Working on: t00550, o9_21496, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.67 seconds
#
# 🔄 [60/64037] Working on: t00550, o9_21496, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 2.79 seconds
#
# 🔄 [61/64037] Working on: t00550, o9_25444, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.45 seconds
#
# 🔄 [62/64037] Working on: t00550, o9_25444, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.31 seconds
#
# 🔄 [63/64037] Working on: t00550, o9_25832, identity
# ⏳ Attempt 1 running HKL...
# ⚠️ Attempt 1 failed: The (1, 0) filling is not obviously S^3
# ⏳ Attempt 2 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.61 seconds
#
# 🔄 [64/64037] Working on: t00550, o9_25832, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.67 seconds
#
# 🔄 [65/64037] Working on: t00550, o9_35720, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 7) ...
# 🟩 Obstruction found! (2, 7)
# ⏱️ Time taken: 3.73 seconds
#
# 🔄 [66/64037] Working on: t00550, o9_35720, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 7) ...
# 🟩 Obstruction found! (2, 7)
# ⏱️ Time taken: 0.54 seconds
#
# 🔄 [67/64037] Working on: t00550, o9_43750, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.43 seconds
#
# 🔄 [68/64037] Working on: t00550, o9_43750, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.97 seconds
#
# 🔄 [69/64037] Working on: t00565, t00565, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (5, 11) ...
#    Looking at (7, 13) ...
# 🟥 No obstruction.
# ⏱️ Time taken: 1.50 seconds
#
# 🔄 [70/64037] Working on: t00565, t01039, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 3.23 seconds
#
# 🔄 [71/64037] Working on: t00565, t01039, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.86 seconds
#
# 🔄 [72/64037] Working on: t00565, t01235, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.18 seconds
#
# 🔄 [73/64037] Working on: t00565, t01235, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.03 seconds
#
# 🔄 [74/64037] Working on: t00565, t01779, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.05 seconds
#
# 🔄 [75/64037] Working on: t00565, t01779, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.00 seconds
#
# 🔄 [76/64037] Working on: t00565, t02069, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (5, 11) ...
# 🟩 Obstruction found! (5, 11)
# ⏱️ Time taken: 2.37 seconds
#
# 🔄 [77/64037] Working on: t00565, t02069, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (5, 11) ...
# 🟩 Obstruction found! (5, 11)
# ⏱️ Time taken: 11.15 seconds
#
# 🔄 [78/64037] Working on: t00565, t02188, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.05 seconds
#
# 🔄 [79/64037] Working on: t00565, t02188, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.13 seconds
#
# 🔄 [80/64037] Working on: t00565, t04507, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (5, 11) ...
# 🟩 Obstruction found! (5, 11)
# ⏱️ Time taken: 3.50 seconds
#
# 🔄 [81/64037] Working on: t00565, t04507, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (5, 11) ...
# 🟩 Obstruction found! (5, 11)
# ⏱️ Time taken: 3.41 seconds
#
# 🔄 [82/64037] Working on: t00565, t05074, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 3.84 seconds
#
# 🔄 [83/64037] Working on: t00565, t05074, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 1.31 seconds
#
# 🔄 [84/64037] Working on: t00565, t05269, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.82 seconds
#
# 🔄 [85/64037] Working on: t00565, t05269, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.83 seconds
#
# 🔄 [86/64037] Working on: t00565, t05288, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 13) ...
# 🟩 Obstruction found! (2, 13)
# ⏱️ Time taken: 1.22 seconds
#
# 🔄 [87/64037] Working on: t00565, t05288, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 13) ...
# 🟩 Obstruction found! (2, 13)
# ⏱️ Time taken: 1.31 seconds
#
# 🔄 [88/64037] Working on: t00565, t05803, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.97 seconds
#
# 🔄 [89/64037] Working on: t00565, t05803, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.82 seconds
#
# 🔄 [90/64037] Working on: t00565, t06119, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.82 seconds
#
# 🔄 [91/64037] Working on: t00565, t06119, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 3.19 seconds
#
# 🔄 [92/64037] Working on: t00565, t06316, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.65 seconds
#
# 🔄 [93/64037] Working on: t00565, t06316, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.67 seconds
#
# 🔄 [94/64037] Working on: t00565, t07168, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.69 seconds
#
# 🔄 [95/64037] Working on: t00565, t07168, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.81 seconds
#
# 🔄 [96/64037] Working on: t00565, t07682, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.05 seconds
#
# 🔄 [97/64037] Working on: t00565, t07682, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.30 seconds
#
# 🔄 [98/64037] Working on: t00565, t08443, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.96 seconds
#
# 🔄 [99/64037] Working on: t00565, t08443, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.09 seconds
#
# 🔄 [100/64037] Working on: t00565, t09218, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 1.26 seconds
#
# 🔄 [101/64037] Working on: t00565, t09218, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 1.45 seconds
#
# 🔄 [102/64037] Working on: t00565, t09613, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.72 seconds
#
# 🔄 [103/64037] Working on: t00565, t09613, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.72 seconds
#
# 🔄 [104/64037] Working on: t00565, t09734, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 3.03 seconds
#
# 🔄 [105/64037] Working on: t00565, t09734, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 0.77 seconds
#
# 🔄 [106/64037] Working on: t00565, t09900, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.90 seconds
#
# 🔄 [107/64037] Working on: t00565, t09900, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.93 seconds
#
# 🔄 [108/64037] Working on: t00565, t09927, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 5) ...
# 🟩 Obstruction found! (3, 5)
# ⏱️ Time taken: 0.93 seconds
#
# 🔄 [109/64037] Working on: t00565, t09927, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 5) ...
# 🟩 Obstruction found! (3, 5)
# ⏱️ Time taken: 0.90 seconds
#
# 🔄 [110/64037] Working on: t00565, t10416, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.74 seconds
#
# 🔄 [111/64037] Working on: t00565, t10416, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.76 seconds
#
# 🔄 [112/64037] Working on: t00565, t10499, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.66 seconds
#
# 🔄 [113/64037] Working on: t00565, t10499, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.70 seconds
#
# 🔄 [114/64037] Working on: t00565, t10558, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.89 seconds
#
# 🔄 [115/64037] Working on: t00565, t10558, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.94 seconds
#
# 🔄 [116/64037] Working on: t00565, t10930, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (5, 11) ...
# 🟩 Obstruction found! (5, 11)
# ⏱️ Time taken: 1.70 seconds
#
# 🔄 [117/64037] Working on: t00565, t10930, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (5, 11) ...
# 🟩 Obstruction found! (5, 11)
# ⏱️ Time taken: 3.77 seconds
#
# 🔄 [118/64037] Working on: t00565, t11034, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.71 seconds
#
# 🔄 [119/64037] Working on: t00565, t11034, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.65 seconds
#
# 🔄 [120/64037] Working on: t00565, t11291, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.66 seconds
#
# 🔄 [121/64037] Working on: t00565, t11291, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.70 seconds
#
# 🔄 [122/64037] Working on: t00565, t11402, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.82 seconds
#
# 🔄 [123/64037] Working on: t00565, t11402, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.84 seconds
#
# 🔄 [124/64037] Working on: t00565, t11489, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 1.14 seconds
#
# 🔄 [125/64037] Working on: t00565, t11489, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 1.06 seconds
#
# 🔄 [126/64037] Working on: t00565, t11497, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 5) ...
# 🟩 Obstruction found! (3, 5)
# ⏱️ Time taken: 0.85 seconds
#
# 🔄 [127/64037] Working on: t00565, t11497, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 5) ...
# 🟩 Obstruction found! (3, 5)
# ⏱️ Time taken: 0.97 seconds
#
# 🔄 [128/64037] Working on: t00565, t11814, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (5, 2) ...
# 🟩 Obstruction found! (5, 2)
# ⏱️ Time taken: 0.78 seconds
#
# 🔄 [129/64037] Working on: t00565, t11814, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (5, 2) ...
# 🟩 Obstruction found! (5, 2)
# ⏱️ Time taken: 0.78 seconds
#
# 🔄 [130/64037] Working on: t00565, t11900, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 3.52 seconds
#
# 🔄 [131/64037] Working on: t00565, t11900, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 1.17 seconds
#
# 🔄 [132/64037] Working on: t00565, t12120, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.93 seconds
#
# 🔄 [133/64037] Working on: t00565, t12120, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.01 seconds
#
# 🔄 [134/64037] Working on: t00565, t12344, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 1.00 seconds
#
# 🔄 [135/64037] Working on: t00565, t12344, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.90 seconds
#
# 🔄 [136/64037] Working on: t00565, t12376, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.87 seconds
#
# 🔄 [137/64037] Working on: t00565, t12376, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.95 seconds
#
# 🔄 [138/64037] Working on: t00565, t12395, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.80 seconds
#
# 🔄 [139/64037] Working on: t00565, t12395, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.64 seconds
#
# 🔄 [140/64037] Working on: t00565, t12757, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.75 seconds
#
# 🔄 [141/64037] Working on: t00565, t12757, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.86 seconds
#
# 🔄 [142/64037] Working on: t00565, o9_00022, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 3.37 seconds
#
# 🔄 [143/64037] Working on: t00565, o9_00022, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 2.01 seconds
#
# 🔄 [144/64037] Working on: t00565, o9_01035, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 1.57 seconds
#
# 🔄 [145/64037] Working on: t00565, o9_01035, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 4.73 seconds
#
# 🔄 [146/64037] Working on: t00565, o9_02163, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.34 seconds
#
# 🔄 [147/64037] Working on: t00565, o9_02163, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.32 seconds
#
# 🔄 [148/64037] Working on: t00565, o9_04950, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 5.71 seconds
#
# 🔄 [149/64037] Working on: t00565, o9_04950, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 2.16 seconds
#
# 🔄 [150/64037] Working on: t00565, o9_05028, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 6.12 seconds
#
# 🔄 [151/64037] Working on: t00565, o9_05028, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 5.77 seconds
#
# 🔄 [152/64037] Working on: t00565, o9_09214, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.05 seconds
#
# 🔄 [153/64037] Working on: t00565, o9_09214, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.84 seconds
#
# 🔄 [154/64037] Working on: t00565, o9_09408, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 5) ...
# 🟩 Obstruction found! (3, 5)
# ⏱️ Time taken: 2.03 seconds
#
# 🔄 [155/64037] Working on: t00565, o9_09408, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 5) ...
# 🟩 Obstruction found! (3, 5)
# ⏱️ Time taken: 4.19 seconds
#
# 🔄 [156/64037] Working on: t00565, o9_10288, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.03 seconds
#
# 🔄 [157/64037] Working on: t00565, o9_10288, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.12 seconds
#
# 🔄 [158/64037] Working on: t00565, o9_10654, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 13) ...
# 🟩 Obstruction found! (2, 13)
# ⏱️ Time taken: 4.30 seconds
#
# 🔄 [159/64037] Working on: t00565, o9_10654, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 13) ...
# 🟩 Obstruction found! (2, 13)
# ⏱️ Time taken: 6.90 seconds
#
# 🔄 [160/64037] Working on: t00565, o9_11161, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.93 seconds
#
# 🔄 [161/64037] Working on: t00565, o9_11161, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 3.61 seconds
#
# 🔄 [162/64037] Working on: t00565, o9_13136, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.95 seconds
#
# 🔄 [163/64037] Working on: t00565, o9_13136, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.27 seconds
#
# 🔄 [164/64037] Working on: t00565, o9_13141, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 13) ...
# 🟩 Obstruction found! (2, 13)
# ⏱️ Time taken: 0.94 seconds
#
# 🔄 [165/64037] Working on: t00565, o9_13141, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 13) ...
# 🟩 Obstruction found! (2, 13)
# ⏱️ Time taken: 0.87 seconds
#
# 🔄 [166/64037] Working on: t00565, o9_13638, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.89 seconds
#
# 🔄 [167/64037] Working on: t00565, o9_13638, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.99 seconds
#
# 🔄 [168/64037] Working on: t00565, o9_16874, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 3.57 seconds
#
# 🔄 [169/64037] Working on: t00565, o9_16874, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 1.38 seconds
#
# 🔄 [170/64037] Working on: t00565, o9_17388, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.36 seconds
#
# 🔄 [171/64037] Working on: t00565, o9_17388, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.61 seconds
#
# 🔄 [172/64037] Working on: t00565, o9_19831, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 13) ...
# 🟩 Obstruction found! (2, 13)
# ⏱️ Time taken: 4.52 seconds
#
# 🔄 [173/64037] Working on: t00565, o9_19831, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 13) ...
# 🟩 Obstruction found! (2, 13)
# ⏱️ Time taken: 7.82 seconds
#
# 🔄 [174/64037] Working on: t00565, o9_20180, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.22 seconds
#
# 🔄 [175/64037] Working on: t00565, o9_20180, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.23 seconds
#
# 🔄 [176/64037] Working on: t00565, o9_20397, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.94 seconds
#
# 🔄 [177/64037] Working on: t00565, o9_20397, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.14 seconds
#
# 🔄 [178/64037] Working on: t00565, o9_20617, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.28 seconds
#
# 🔄 [179/64037] Working on: t00565, o9_20617, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.22 seconds
#
# 🔄 [180/64037] Working on: t00565, o9_20956, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 4.35 seconds
#
# 🔄 [181/64037] Working on: t00565, o9_20956, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 4.13 seconds
#
# 🔄 [182/64037] Working on: t00565, o9_22199, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.86 seconds
#
# 🔄 [183/64037] Working on: t00565, o9_22199, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.93 seconds
#
# 🔄 [184/64037] Working on: t00565, o9_22337, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
#    Looking at (5, 11) ...
# 🟩 Obstruction found! (5, 11)
# ⏱️ Time taken: 4.17 seconds
#
# 🔄 [185/64037] Working on: t00565, o9_22337, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
#    Looking at (5, 11) ...
# 🟩 Obstruction found! (5, 11)
# ⏱️ Time taken: 1.80 seconds
#
# 🔄 [186/64037] Working on: t00565, o9_22550, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (5, 11) ...
# 🟩 Obstruction found! (5, 11)
# ⏱️ Time taken: 2.47 seconds
#
# 🔄 [187/64037] Working on: t00565, o9_22550, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (5, 11) ...
# 🟩 Obstruction found! (5, 11)
# ⏱️ Time taken: 1.71 seconds
#
# 🔄 [188/64037] Working on: t00565, o9_22790, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 17) ...
# 🟩 Obstruction found! (3, 17)
# ⏱️ Time taken: 2.24 seconds
#
# 🔄 [189/64037] Working on: t00565, o9_22790, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 17) ...
# 🟩 Obstruction found! (3, 17)
# ⏱️ Time taken: 1.94 seconds
#
# 🔄 [190/64037] Working on: t00565, o9_23094, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 4.71 seconds
#
# 🔄 [191/64037] Working on: t00565, o9_23094, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 4.33 seconds
#
# 🔄 [192/64037] Working on: t00565, o9_23786, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
#    Looking at (5, 2) ...
# 🟩 Obstruction found! (5, 2)
# ⏱️ Time taken: 1.47 seconds
#
# 🔄 [193/64037] Working on: t00565, o9_23786, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
#    Looking at (5, 2) ...
# 🟩 Obstruction found! (5, 2)
# ⏱️ Time taken: 1.61 seconds
#
# 🔄 [194/64037] Working on: t00565, o9_24670, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 4.19 seconds
#
# 🔄 [195/64037] Working on: t00565, o9_24670, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 6.97 seconds
#
# 🔄 [196/64037] Working on: t00565, o9_27079, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.16 seconds
#
# 🔄 [197/64037] Working on: t00565, o9_27079, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.86 seconds
#
# 🔄 [198/64037] Working on: t00565, o9_27215, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.81 seconds
#
# 🔄 [199/64037] Working on: t00565, o9_27215, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.90 seconds
#
# 🔄 [200/64037] Working on: t00565, o9_28874, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.95 seconds
#
# 🔄 [201/64037] Working on: t00565, o9_28874, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.00 seconds
#
# 🔄 [202/64037] Working on: t00565, o9_29669, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.95 seconds
#
# 🔄 [203/64037] Working on: t00565, o9_29669, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.80 seconds
#
# 🔄 [204/64037] Working on: t00565, o9_29916, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.19 seconds
#
# 🔄 [205/64037] Working on: t00565, o9_29916, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 3.62 seconds
#
# 🔄 [206/64037] Working on: t00565, o9_30018, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 1.05 seconds
#
# 🔄 [207/64037] Working on: t00565, o9_30018, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 1.02 seconds
#
# 🔄 [208/64037] Working on: t00565, o9_30147, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 1.36 seconds
#
# 🔄 [209/64037] Working on: t00565, o9_30147, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 1.15 seconds
#
# 🔄 [210/64037] Working on: t00565, o9_31990, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.01 seconds
#
# 🔄 [211/64037] Working on: t00565, o9_31990, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.95 seconds
#
# 🔄 [212/64037] Working on: t00565, o9_33067, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.43 seconds
#
# 🔄 [213/64037] Working on: t00565, o9_33067, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 3.90 seconds
#
# 🔄 [214/64037] Working on: t00565, o9_33452, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.39 seconds
#
# 🔄 [215/64037] Working on: t00565, o9_33452, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.22 seconds
#
# 🔄 [216/64037] Working on: t00565, o9_33834, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.75 seconds
#
# 🔄 [217/64037] Working on: t00565, o9_33834, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.84 seconds
#
# 🔄 [218/64037] Working on: t00565, o9_33966, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.02 seconds
#
# 🔄 [219/64037] Working on: t00565, o9_33966, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.84 seconds
#
# 🔄 [220/64037] Working on: t00565, o9_34323, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.33 seconds
#
# 🔄 [221/64037] Working on: t00565, o9_34323, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.18 seconds
#
# 🔄 [222/64037] Working on: t00565, o9_34676, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 2.87 seconds
#
# 🔄 [223/64037] Working on: t00565, o9_34676, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.73 seconds
#
# 🔄 [224/64037] Working on: t00565, o9_34743, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.99 seconds
#
# 🔄 [225/64037] Working on: t00565, o9_34743, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.91 seconds
#
# 🔄 [226/64037] Working on: t00565, o9_34801, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.90 seconds
#
# 🔄 [227/64037] Working on: t00565, o9_34801, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.97 seconds
#
# 🔄 [228/64037] Working on: t00565, o9_34908, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.05 seconds
#
# 🔄 [229/64037] Working on: t00565, o9_34908, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.19 seconds
#
# 🔄 [230/64037] Working on: t00565, o9_35003, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 1.10 seconds
#
# 🔄 [231/64037] Working on: t00565, o9_35003, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 1.34 seconds
#
# 🔄 [232/64037] Working on: t00565, o9_36320, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.92 seconds
#
# 🔄 [233/64037] Working on: t00565, o9_36320, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 2.98 seconds
#
# 🔄 [234/64037] Working on: t00565, o9_36873, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.90 seconds
#
# 🔄 [235/64037] Working on: t00565, o9_36873, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 3.71 seconds
#
# 🔄 [236/64037] Working on: t00565, o9_37080, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 0.73 seconds
#
# 🔄 [237/64037] Working on: t00565, o9_37080, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 0.71 seconds
#
# 🔄 [238/64037] Working on: t00565, o9_37485, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 0.77 seconds
#
# 🔄 [239/64037] Working on: t00565, o9_37485, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 0.76 seconds
#
# 🔄 [240/64037] Working on: t00565, o9_37563, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 1.48 seconds
#
# 🔄 [241/64037] Working on: t00565, o9_37563, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 1.19 seconds
#
# 🔄 [242/64037] Working on: t00565, o9_37731, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.02 seconds
#
# 🔄 [243/64037] Working on: t00565, o9_37731, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.94 seconds
#
# 🔄 [244/64037] Working on: t00565, o9_37732, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.70 seconds
#
# 🔄 [245/64037] Working on: t00565, o9_37732, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.65 seconds
#
# 🔄 [246/64037] Working on: t00565, o9_37761, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 3.86 seconds
#
# 🔄 [247/64037] Working on: t00565, o9_37761, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.90 seconds
#
# 🔄 [248/64037] Working on: t00565, o9_38364, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.01 seconds
#
# 🔄 [249/64037] Working on: t00565, o9_38364, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.84 seconds
#
# 🔄 [250/64037] Working on: t00565, o9_38471, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 7) ...
# 🟩 Obstruction found! (3, 7)
# ⏱️ Time taken: 0.87 seconds
#
# 🔄 [251/64037] Working on: t00565, o9_38471, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 7) ...
# 🟩 Obstruction found! (3, 7)
# ⏱️ Time taken: 1.56 seconds
#
# 🔄 [252/64037] Working on: t00565, o9_38975, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.99 seconds
#
# 🔄 [253/64037] Working on: t00565, o9_38975, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.74 seconds
#
# 🔄 [254/64037] Working on: t00565, o9_39266, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.19 seconds
#
# 🔄 [255/64037] Working on: t00565, o9_39266, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.15 seconds
#
# 🔄 [256/64037] Working on: t00565, o9_39339, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 3.50 seconds
#
# 🔄 [257/64037] Working on: t00565, o9_39339, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.72 seconds
#
# 🔄 [258/64037] Working on: t00565, o9_39369, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.76 seconds
#
# 🔄 [259/64037] Working on: t00565, o9_39369, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 4.18 seconds
#
# 🔄 [260/64037] Working on: t00565, o9_39591, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 7) ...
# 🟩 Obstruction found! (3, 7)
# ⏱️ Time taken: 0.85 seconds
#
# 🔄 [261/64037] Working on: t00565, o9_39591, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 7) ...
# 🟩 Obstruction found! (3, 7)
# ⏱️ Time taken: 0.98 seconds
#
# 🔄 [262/64037] Working on: t00565, o9_39887, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.08 seconds
#
# 🔄 [263/64037] Working on: t00565, o9_39887, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.97 seconds
#
# 🔄 [264/64037] Working on: t00565, o9_40081, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 1.03 seconds
#
# 🔄 [265/64037] Working on: t00565, o9_40081, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 1.07 seconds
#
# 🔄 [266/64037] Working on: t00565, o9_40192, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 4.00 seconds
#
# 🔄 [267/64037] Working on: t00565, o9_40192, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.32 seconds
#
# 🔄 [268/64037] Working on: t00565, o9_40449, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.03 seconds
#
# 🔄 [269/64037] Working on: t00565, o9_40449, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.39 seconds
#
# 🔄 [270/64037] Working on: t00565, o9_40522, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.77 seconds
#
# 🔄 [271/64037] Working on: t00565, o9_40522, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.91 seconds
#
# 🔄 [272/64037] Working on: t00565, o9_40547, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 1.52 seconds
#
# 🔄 [273/64037] Working on: t00565, o9_40547, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 4.95 seconds
#
# 🔄 [274/64037] Working on: t00565, o9_40803, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 1.85 seconds
#
# 🔄 [275/64037] Working on: t00565, o9_40803, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 4.69 seconds
#
# 🔄 [276/64037] Working on: t00565, o9_41611, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.80 seconds
#
# 🔄 [277/64037] Working on: t00565, o9_41611, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.74 seconds
#
# 🔄 [278/64037] Working on: t00565, o9_41678, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 4.19 seconds
#
# 🔄 [279/64037] Working on: t00565, o9_41678, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 4.62 seconds
#
# 🔄 [280/64037] Working on: t00565, o9_41995, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.77 seconds
#
# 🔄 [281/64037] Working on: t00565, o9_41995, reverse_mirror
# ⏳ Attempt 1 running HKL...
# ...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.34 seconds
#
# 🔄 [7319/64037] Working on: t05899, t10645, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.38 seconds
#
# 🔄 [7320/64037] Working on: t05899, t10645, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.30 seconds
#
# 🔄 [7321/64037] Working on: t05899, t11441, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.55 seconds
#
# 🔄 [7322/64037] Working on: t05899, t11441, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.54 seconds
#
# 🔄 [7323/64037] Working on: t05899, t11441, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.64 seconds
#
# 🔄 [7324/64037] Working on: t05899, t11441, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.51 seconds
#
# 🔄 [7325/64037] Working on: t05899, t11462, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.34 seconds
#
# 🔄 [7326/64037] Working on: t05899, t11462, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.34 seconds
#
# 🔄 [7327/64037] Working on: t05899, t11462, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.40 seconds
#
# 🔄 [7328/64037] Working on: t05899, t11462, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.31 seconds
#
# 🔄 [7329/64037] Working on: t05899, t11748, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
# 🟩 Obstruction found! (2, 11)
# ⏱️ Time taken: 0.48 seconds
#
# 🔄 [7330/64037] Working on: t05899, t11748, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
# 🟩 Obstruction found! (2, 11)
# ⏱️ Time taken: 0.44 seconds
#
# 🔄 [7331/64037] Working on: t05899, t11748, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
# 🟩 Obstruction found! (2, 11)
# ⏱️ Time taken: 0.41 seconds
#
# 🔄 [7332/64037] Working on: t05899, t11748, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
# 🟩 Obstruction found! (2, 11)
# ⏱️ Time taken: 0.36 seconds
#
# 🔄 [7333/64037] Working on: t05899, t11898, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.36 seconds
#
# 🔄 [7334/64037] Working on: t05899, t11898, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.31 seconds
#
# 🔄 [7335/64037] Working on: t05899, t11898, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.33 seconds
#
# 🔄 [7336/64037] Working on: t05899, t11898, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.32 seconds
#
# 🔄 [7337/64037] Working on: t05899, t12270, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.48 seconds
#
# 🔄 [7338/64037] Working on: t05899, t12270, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.42 seconds
#
# 🔄 [7339/64037] Working on: t05899, t12270, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.41 seconds
#
# 🔄 [7340/64037] Working on: t05899, t12270, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.41 seconds
#
# 🔄 [7341/64037] Working on: t05899, t12271, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.17 seconds
#
# 🔄 [7342/64037] Working on: t05899, t12271, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.16 seconds
#
# 🔄 [7343/64037] Working on: t05899, t12271, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.17 seconds
#
# 🔄 [7344/64037] Working on: t05899, t12271, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.16 seconds
#
# 🔄 [7345/64037] Working on: t05899, t12388, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.50 seconds
#
# 🔄 [7346/64037] Working on: t05899, t12388, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.43 seconds
#
# 🔄 [7347/64037] Working on: t05899, t12388, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.49 seconds
#
# 🔄 [7348/64037] Working on: t05899, t12388, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 2.49 seconds
#
# 🔄 [7349/64037] Working on: t05899, t12656, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 7) ...
# 🟩 Obstruction found! (2, 7)
# ⏱️ Time taken: 0.31 seconds
#
# 🔄 [7350/64037] Working on: t05899, t12656, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 7) ...
# 🟩 Obstruction found! (2, 7)
# ⏱️ Time taken: 0.19 seconds
#
# 🔄 [7351/64037] Working on: t05899, t12656, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 7) ...
# 🟩 Obstruction found! (2, 7)
# ⏱️ Time taken: 0.20 seconds
#
# 🔄 [7352/64037] Working on: t05899, t12656, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 7) ...
# 🟩 Obstruction found! (2, 7)
# ⏱️ Time taken: 0.22 seconds
#
# 🔄 [7353/64037] Working on: t05899, t12679, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.54 seconds
#
# 🔄 [7354/64037] Working on: t05899, t12679, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.45 seconds
#
# 🔄 [7355/64037] Working on: t05899, t12679, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.60 seconds
#
# 🔄 [7356/64037] Working on: t05899, t12679, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.48 seconds
#
# 🔄 [7357/64037] Working on: t05899, o9_00017, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.64 seconds
#
# 🔄 [7358/64037] Working on: t05899, o9_00017, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.43 seconds
#
# 🔄 [7359/64037] Working on: t05899, o9_00017, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.48 seconds
#
# 🔄 [7360/64037] Working on: t05899, o9_00017, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.59 seconds
#
# 🔄 [7361/64037] Working on: t05899, o9_01024, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.79 seconds
#
# 🔄 [7362/64037] Working on: t05899, o9_01024, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.02 seconds
#
# 🔄 [7363/64037] Working on: t05899, o9_01024, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.81 seconds
#
# 🔄 [7364/64037] Working on: t05899, o9_01024, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.84 seconds
#
# 🔄 [7365/64037] Working on: t05899, o9_02030, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.68 seconds
#
# 🔄 [7366/64037] Working on: t05899, o9_02030, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.66 seconds
#
# 🔄 [7367/64037] Working on: t05899, o9_02030, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.73 seconds
#
# 🔄 [7368/64037] Working on: t05899, o9_02030, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.53 seconds
#
# 🔄 [7369/64037] Working on: t05899, o9_04037, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
# 🟩 Obstruction found! (2, 11)
# ⏱️ Time taken: 3.34 seconds
#
# 🔄 [7370/64037] Working on: t05899, o9_04037, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
# 🟩 Obstruction found! (2, 11)
# ⏱️ Time taken: 1.72 seconds
#
# 🔄 [7371/64037] Working on: t05899, o9_04037, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
# 🟩 Obstruction found! (2, 11)
# ⏱️ Time taken: 1.55 seconds
#
# 🔄 [7372/64037] Working on: t05899, o9_04037, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
# 🟩 Obstruction found! (2, 11)
# ⏱️ Time taken: 1.28 seconds
#
# 🔄 [7373/64037] Working on: t05899, o9_04139, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 3.41 seconds
#
# 🔄 [7374/64037] Working on: t05899, o9_04139, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 1.97 seconds
#
# 🔄 [7375/64037] Working on: t05899, o9_04139, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 3.84 seconds
#
# 🔄 [7376/64037] Working on: t05899, o9_04139, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 3.75 seconds
#
# 🔄 [7377/64037] Working on: t05899, o9_10817, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 4.43 seconds
#
# 🔄 [7378/64037] Working on: t05899, o9_10817, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 4.57 seconds
#
# 🔄 [7379/64037] Working on: t05899, o9_10817, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 4.66 seconds
#
# 🔄 [7380/64037] Working on: t05899, o9_10817, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 5) ...
# 🟩 Obstruction found! (2, 5)
# ⏱️ Time taken: 6.24 seconds
#
# 🔄 [7381/64037] Working on: t05899, o9_13273, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.38 seconds
#
# 🔄 [7382/64037] Working on: t05899, o9_13273, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.66 seconds
#
# 🔄 [7383/64037] Working on: t05899, o9_13273, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.73 seconds
#
# 🔄 [7384/64037] Working on: t05899, o9_13273, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.37 seconds
#
# 🔄 [7385/64037] Working on: t05899, o9_16248, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.34 seconds
#
# 🔄 [7386/64037] Working on: t05899, o9_16248, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.30 seconds
#
# 🔄 [7387/64037] Working on: t05899, o9_16248, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.32 seconds
#
# 🔄 [7388/64037] Working on: t05899, o9_16248, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
#    Looking at (3, 2) ...
# 🟩 Obstruction found! (3, 2)
# ⏱️ Time taken: 0.33 seconds
#
# 🔄 [7389/64037] Working on: t05899, o9_19031, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.51 seconds
#
# 🔄 [7390/64037] Working on: t05899, o9_19031, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.54 seconds
#
# 🔄 [7391/64037] Working on: t05899, o9_19031, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.57 seconds
#
# 🔄 [7392/64037] Working on: t05899, o9_19031, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.55 seconds
#
# 🔄 [7393/64037] Working on: t05899, o9_19326, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
#    Looking at (3, 5) ...
#    Looking at (5, 19) ...
#    Looking at (7, 13) ...
# 🟥 No obstruction.
# ⏱️ Time taken: 0.69 seconds
#
# 🔄 [7394/64037] Working on: t05899, o9_19326, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
#    Looking at (3, 5) ...
#    Looking at (5, 19) ...
#    Looking at (7, 13) ...
# 🟥 No obstruction.
# ⏱️ Time taken: 0.73 seconds
#
# 🔄 [7395/64037] Working on: t05899, o9_19326, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
#    Looking at (3, 5) ...
#    Looking at (5, 19) ...
#    Looking at (7, 13) ...
# 🟥 No obstruction.
# ⏱️ Time taken: 0.75 seconds
#
# 🔄 [7396/64037] Working on: t05899, o9_19326, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
#    Looking at (2, 11) ...
#    Looking at (3, 5) ...
#    Looking at (5, 19) ...
#    Looking at (7, 13) ...
# 🟥 No obstruction.
# ⏱️ Time taken: 0.71 seconds
#
# 🔄 [7397/64037] Working on: t05899, o9_22951, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.67 seconds
#
# 🔄 [7398/64037] Working on: t05899, o9_22951, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 2.55 seconds
#
# 🔄 [7399/64037] Working on: t05899, o9_22951, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.72 seconds
#
# 🔄 [7400/64037] Working on: t05899, o9_22951, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.86 seconds
#
# 🔄 [7401/64037] Working on: t05899, o9_23147, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.40 seconds
#
# 🔄 [7402/64037] Working on: t05899, o9_23147, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.38 seconds
#
# 🔄 [7403/64037] Working on: t05899, o9_23147, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.55 seconds
#
# 🔄 [7404/64037] Working on: t05899, o9_23147, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.45 seconds
#
# 🔄 [7405/64037] Working on: t05899, o9_24293, identity
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.89 seconds
#
# 🔄 [7406/64037] Working on: t05899, o9_24293, reverse
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.67 seconds
#
# 🔄 [7407/64037] Working on: t05899, o9_24293, mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.76 seconds
#
# 🔄 [7408/64037] Working on: t05899, o9_24293, reverse_mirror
# ⏳ Attempt 1 running HKL...
#    Looking at (2, 3) ...
# 🟩 Obstruction found! (2, 3)
# ⏱️ Time taken: 0.95 seconds
#
# 🔄 [7409/64037] Working on: t05899, o9_27165, identity
